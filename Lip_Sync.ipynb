# %%
# !pip install gtts

# %%
# !pip install opencv-python

# %%
from gtts import gTTS
import os

# %%
from os.path import exists, join, basename, splitext

# %%
script = """Namaste Mathangi! My name is Anika, and I’m here to guide you through managing your credit card dues. Mathangi, as of today, your credit card bill shows an amount due of INR 5,053 which needs to be paid by 31st December 2024.
Missing this payment could lead to two significant consequences:
First, a late fee will be added to your outstanding balance.
Second, your credit score will be negatively impacted, which may affect your future borrowing ability.
Make your payment by clicking the link here... Pay through UPI or bank transfer.
Thank you!"""
language = "en"

# %%
output = gTTS(text=script, lang=language, slow=False)
output.save("/content/input.wav")
os.system("start /content/input.wav")
# Out:
# 32512

# %%
from IPython.display import Audio
import os

AUDIO_URL = './input/input.wav'
audio_name = os.path.basename(AUDIO_URL)

Audio(AUDIO_URL)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import os

IMAGE_URL = './input/Screenshot.png'
image_name = os.path.basename(IMAGE_URL)  

img = plt.imread(IMAGE_URL)  
plt.imshow(img)
plt.show()

# %%
import cv2


image = cv2.imread("./input/Screenshot.png")


fps = 30  # Frames per second

video_duration = 30  # Video duration in seconds


total_frames = int(fps * video_duration)

video_writer = cv2.VideoWriter("./input/input_video.mp4", cv2.VideoWriter_fourcc('m','p','e','g'), fps, (image.shape[1], image.shape[0]))


for _ in range(total_frames):

    video_writer.write(image)


video_writer.release()

print("Video created successfully!")
# Out:
# Video created successfully!

# %% [markdown]
# # Wav2lip

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Get the code and models

# %%
! git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# fatal: destination path 'Wav2Lip' already exists and is not an empty directory.

# %%
# !ls /content/gdrive/MyDrive/wav2lip
# Out:
# wav2lip_gan.pth

# %%
# !cp -ri "/content/gdrive/MyDrive/wav2lip/wav2lip_gan.pth" /content/Wav2Lip/checkpoints/

# %%
# !pip uninstall tensorflow tensorflow-gpu
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Would remove:
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.11/dist-packages/tensorflow-2.18.0.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/tensorflow/*
# Proceed (Y/n)? Y
#   Successfully uninstalled tensorflow-2.18.0
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
# !cd Wav2Lip && pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 59.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: Ignored the following yanked versions: 3.4.11.39, 3.4.17.61, 4.4.0.42, 4.4.0.44, 4.5.4.58, 4.5.5.62, 4.7.0.68
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ...

# %%
# !wget "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" -O "Wav2Lip/face_detection/detection/sfd/s3fd.pth"
# Out:
# --2025-02-26 08:26:33--  https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth
# Resolving www.adrianbulat.com (www.adrianbulat.com)... 45.136.29.207
# Connecting to www.adrianbulat.com (www.adrianbulat.com)|45.136.29.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89843225 (86M) [application/octet-stream]
# Saving to: ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’
#
# Wav2Lip/face_detect 100%[===================>]  85.68M  17.4MB/s    in 6.2s
#
# 2025-02-26 08:26:40 (13.9 MB/s) - ‘Wav2Lip/face_detection/detection/sfd/s3fd.pth’ saved [89843225/89843225]

# %% [markdown]
# Get Result from input video and audio

# %%
# !pip install librosa==0.9.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 78.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# ...

# %% [markdown]
# downloading librosa==0.9.1 because latest version gives error

# %%
# !cd Wav2Lip && python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "./input/input_video.mp4" --audio "./input/input.wav"
# Out:
# Using cuda for inference.
# Reading video frames...
# Number of frames available for inference: 900
# /content/Wav2Lip/audio.py:100: FutureWarning: Pass sr=16000, n_fft=800 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.filters.mel(hp.sample_rate, hp.n_fft, n_mels=hp.num_mels,
# (80, 3700)
# Length of mel chunks: 1383
# ...

# %%
# use the "files" button on the left to download the result in the Wav2Lip/results/ folder.
# !cp "/content/Wav2Lip/results/result_voice.mp4" "./output/"

# %%
from IPython.display import Video

VIDEO_PATH = "./output/result_voice.mp4"  # Change this to your video file path
Video(VIDEO_PATH, width=600, embed=True)  # Adjust width as needed
# Out:
# <video controls  width="600" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
